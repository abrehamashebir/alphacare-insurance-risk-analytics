# %%
import sys
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sys.path.append("../src")

# %%
file_path= "../datasets/insurance_data_cleaned.csv"

# %%
from insurance_visualization import univariate_visualization, bivariate_visualization

# %%
df = pd.read_csv(file_path)
# Out:
# /tmp/ipykernel_6471/2618208116.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
univariate_columns = [ 'IsVATRegistered', 'Citizenship', 'LegalType', 
       'Bank', 'AccountType', 'MaritalStatus', 'Gender',  'Province',
       'PostalCode', 'ItemType', 'mmcode',
       'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
       'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
       'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
       'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
       'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
       'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
       'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
       'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
       'TotalClaims']

# %%
for column in univariate_columns:
    univariate_visualization(df, column)

# %%
gender_specified = df[df['Gender'] != 'Not specified']

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified,x='Gender',y='TotalPremium', palette='Set2')
plt.title('Total Premium Per Gender"')
plt.xlabel('Gender')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/total_premium')
plt.show()
# Out:
# /tmp/ipykernel_6471/3636441628.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified,x='Gender',y='TotalPremium', palette='Set2')

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified, x='Province', y='TotalPremium', palette='Set2')
plt.title('Total Premium Per Province')
plt.xlabel('Province')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/total_premium_per_province')
plt.show()
# Out:
# /tmp/ipykernel_6471/1816137533.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified, x='Province', y='TotalPremium', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified, x='VehicleType', y='TotalClaims', palette='Set2')
plt.title('Total Claims Per VehicleType')
plt.xlabel('VehicleType')
plt.ylabel('Total Claims')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/TotalClaims_per_VehicleType')
plt.show()
# Out:
# /tmp/ipykernel_6471/3322312628.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified, x='VehicleType', y='TotalClaims', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified, x='VehicleType', y='TotalPremium', palette='Set2')
plt.title(' Total Premium Per VehicleType')
plt.xlabel('VehicleType')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/total_premium_per_vehicle')
plt.show()
# Out:
# /tmp/ipykernel_6471/1326946315.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified, x='VehicleType', y='TotalPremium', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=gender_specified, x='SumInsured', y='TotalClaims', palette='Set2')
plt.title(' Total SumInsured vs TotalClaims')
plt.xlabel('SumInsured')
plt.ylabel('TotalClaims')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/tSumInsured_vs_TotalClaims')
plt.show()
# Out:
# /tmp/ipykernel_6471/1676693230.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=gender_specified, x='SumInsured', y='TotalClaims', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=gender_specified, x='CoverType', y='TotalClaims', palette='Set2')
plt.title('TotalClaims Per CoverType')
plt.xlabel('CoverType')
plt.ylabel('TotalClaims')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/TotalClaims_per_CoverType')
plt.show()
# Out:
# /tmp/ipykernel_6471/2272656762.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=gender_specified, x='CoverType', y='TotalClaims', palette='Set2')
