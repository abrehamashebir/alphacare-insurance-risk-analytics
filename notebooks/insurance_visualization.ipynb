# %%
import sys
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sys.path.append("../src")

# %%
file_path= "../datasets/insurance_data_cleaned.csv"

# %%
from insurance_visualization import univariate_visualization, bivariate_visualization

# %%
df = pd.read_csv(file_path)
# Out:
# /tmp/ipykernel_6471/2618208116.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
univariate_columns = [ 'IsVATRegistered', 'Citizenship', 'LegalType', 
       'Bank', 'AccountType', 'MaritalStatus', 'Gender',  'Province',
       'PostalCode', 'ItemType', 'mmcode',
       'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
       'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
       'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
       'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
       'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
       'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
       'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
       'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
       'TotalClaims']

# %%
for column in univariate_columns:
    univariate_visualization(df, column)

# %%
gender_specified = df[df['Gender'] != 'Not specified']

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified,x='Gender',y='TotalPremium', palette='Set2')
plt.title('Total Premium Per Gender"')
plt.xlabel('Gender')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/total_premium')
plt.show()
# Out:
# /tmp/ipykernel_6471/3636441628.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified,x='Gender',y='TotalPremium', palette='Set2')

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified, x='Province', y='TotalPremium', palette='Set2')
plt.title('Total Premium Per Province')
plt.xlabel('Province')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/total_premium_per_province')
plt.show()
# Out:
# /tmp/ipykernel_6471/1816137533.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified, x='Province', y='TotalPremium', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified, x='VehicleType', y='TotalClaims', palette='Set2')
plt.title('Total Claims Per VehicleType')
plt.xlabel('VehicleType')
plt.ylabel('Total Claims')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/TotalClaims_per_VehicleType')
plt.show()
# Out:
# /tmp/ipykernel_6471/3322312628.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified, x='VehicleType', y='TotalClaims', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_specified, x='VehicleType', y='TotalPremium', palette='Set2')
plt.title(' Total Premium Per VehicleType')
plt.xlabel('VehicleType')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/total_premium_per_vehicle')
plt.show()
# Out:
# /tmp/ipykernel_6471/1326946315.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_specified, x='VehicleType', y='TotalPremium', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=gender_specified, x='SumInsured', y='TotalClaims', palette='Set2')
plt.title(' Total SumInsured vs TotalClaims')
plt.xlabel('SumInsured')
plt.ylabel('TotalClaims')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/tSumInsured_vs_TotalClaims')
plt.show()
# Out:
# /tmp/ipykernel_6471/1676693230.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=gender_specified, x='SumInsured', y='TotalClaims', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=gender_specified, x='CoverType', y='TotalClaims', palette='Set2')
plt.title('TotalClaims Per CoverType')
plt.xlabel('CoverType')
plt.ylabel('TotalClaims')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/TotalClaims_per_CoverType')
plt.show()
# Out:
# /tmp/ipykernel_6471/2272656762.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=gender_specified, x='CoverType', y='TotalClaims', palette='Set2')

# %%
# Ensure date is in datetime format
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])

# Group by month and PostalCode
monthly_grouped = df.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode'])[['TotalPremium', 'TotalClaims']].sum().reset_index()
monthly_grouped
# Out:
# /tmp/ipykernel_6471/2928398656.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_grouped = df.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode'])[['TotalPremium', 'TotalClaims']].sum().reset_index()
#      TransactionMonth  PostalCode  TotalPremium   TotalClaims
# 0          2013-10-31        7405    151.867402      0.000000
# 1          2013-10-31        7766    172.206933      0.000000
# 2          2013-10-31        7945     46.989177      0.000000
# 3          2013-11-30           1   1432.740561  50585.078947
# 4          2013-11-30          84    120.874211      0.000000
# ...               ...         ...           ...           ...
# 9701       2015-08-31        9781   2986.113947      0.000000
# 9702       2015-08-31        9830   1098.941930      0.000000
# 9703       2015-08-31        9868   1160.423772      0.000000
# 9704       2015-08-31        9869   7530.830877   2236.842105
# ...

# %%
# Sort to ensure proper diff
monthly_grouped = monthly_grouped.sort_values(by=['PostalCode', 'TransactionMonth'])

# Calculate monthly change per PostalCode
monthly_grouped['PremiumChange'] = monthly_grouped.groupby('PostalCode')['TotalPremium'].diff()
monthly_grouped['ClaimsChange'] = monthly_grouped.groupby('PostalCode')['TotalClaims'].diff()

# Drop NaNs from the first month per group
monthly_change = monthly_grouped.dropna(subset=['PremiumChange', 'ClaimsChange'])

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=monthly_change, x='PremiumChange', y='ClaimsChange', hue='PostalCode', alpha=0.6)
plt.title("Monthly Change: TotalPremium vs TotalClaims by Zip Code")
plt.xlabel("Change in Total Premium")
plt.ylabel("Change in Total Claims")
plt.legend(title='PostalCode', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Pivot the changes for correlation matrix per ZipCode
pivot_corr = monthly_change.pivot_table(index='TransactionMonth', columns='PostalCode', values=['PremiumChange', 'ClaimsChange'])

# Drop columns where data is too sparse (optional)
pivot_corr = pivot_corr.dropna(axis=1, how='any')

# Calculate correlation between changes
corrs = []
for pc in pivot_corr['PremiumChange'].columns:
    if pc in pivot_corr['ClaimsChange']:
        corr_val = pivot_corr['PremiumChange'][pc].corr(pivot_corr['ClaimsChange'][pc])
        corrs.append({'PostalCode': pc, 'Correlation': corr_val})

# Convert to DataFrame and display
corr_df = pd.DataFrame(corrs).dropna().sort_values(by='Correlation', ascending=False)
corr_df.head(10)  # Top 10 zip codes where claims and premium changes correlate
# Out:
# /home/age/KAIM-Projects/alphacare-insurance-risk-analytics/.insurance-venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3063: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/age/KAIM-Projects/alphacare-insurance-risk-analytics/.insurance-venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3064: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
#    PostalCode  Correlation
# 0        7405     0.622612
# 2        7945     0.107327

# %%
# Combine premium and claims changes
corr_matrix = monthly_change.groupby('PostalCode')[['PremiumChange', 'ClaimsChange']].corr().unstack().iloc[:,1]

plt.figure(figsize=(10, 6))
sns.histplot(corr_matrix, bins=30, kde=True)
plt.title("Distribution of Correlation Between Premium and Claims Changes by Zip Code")
plt.xlabel("Correlation Coefficient")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Trends Over Geography

# %%
df_geo = df.dropna(subset=['CoverType', 'TotalPremium', 'make', 'PostalCode'])
df_geo = df_geo[df_geo['CoverType'] != 'Not Specified']

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='Province', hue='CoverType')
plt.title("Insurance Cover Types Across Provinces")
plt.xticks(rotation=45)
plt.legend(title='Cover Type')
plt.tight_layout()
plt.show()

# %%
cover_by_zone_month = df.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode', 'CoverType']).size().reset_index(name='count')

# Example: filter to top 3 zones for clarity
top_zones = cover_by_zone_month['PostalCode'].value_counts().head(3).index
filtered = cover_by_zone_month[cover_by_zone_month['PostalCode'].isin(top_zones)]

plt.figure(figsize=(14,6))
sns.lineplot(data=filtered, x='TransactionMonth', y='count', hue='CoverType', style='PostalCode')
plt.title("Monthly Trend of Cover Types by PostalCode")
plt.show()
# Out:
# /tmp/ipykernel_6471/578872347.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   cover_by_zone_month = df.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode', 'CoverType']).size().reset_index(name='count')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='TransactionMonth', y='TotalPremium', hue='CoverType', ci=None)
plt.title("Monthly Total Premium by Cover Type")
plt.xlabel("Transaction Month")
plt.ylabel("Total Premium")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/monthly_total_premium_by_cover_type')
plt.show()
# Out:
# /tmp/ipykernel_6471/677384012.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x='TransactionMonth', y='TotalPremium', hue='CoverType', ci=None)

# %%
df_grouped = df.groupby(['TransactionMonth', 'PostalCode']).agg(
                      {'TotalPremium': 'sum', 'TotalClaims': 'sum'}).reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped, x='TransactionMonth', y='TotalPremium', hue='PostalCode', marker='o')
plt.title("Monthly Total Premium by Postal Code")
plt.xlabel("Transaction Month")
plt.ylabel("Total Premium")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
premium_by_province = df.groupby('Province')['TotalPremium'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
premium_by_province.plot(kind='bar', color='skyblue')
plt.title("Average Total Premium by Province")
plt.ylabel("Mean Premium")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_zips = df['PostalCode'].value_counts().head(5).index
filtered = df[df['PostalCode'].isin(top_zips)]

monthly_prem = filtered.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode'])['TotalPremium'].mean().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_prem, x='TransactionMonth', y='TotalPremium', hue='PostalCode')
plt.title("Premium Trends Over Time by PostalCode")
plt.ylabel("Avg Monthly Premium")
plt.show()
# Out:
# /tmp/ipykernel_6471/3973323354.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_prem = filtered.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode'])['TotalPremium'].mean().reset_index()

# %%
monthly_claim = filtered.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode'])['TotalClaims'].mean().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_claim, x='TransactionMonth', y='TotalClaims', hue='PostalCode')
plt.title("Claim Trends Over Time by PostalCode")
plt.ylabel("Avg Monthly Claims")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6471/626399382.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_claim = filtered.groupby([pd.Grouper(key='TransactionMonth', freq='M'), 'PostalCode'])['TotalClaims'].mean().reset_index()

# %%
df['CapitalOutstanding'] = df['CapitalOutstanding'].replace({'Not Specified': np.nan, '0': 0}).astype(float)

# %%
df['CapitalOutstanding'] = df['CapitalOutstanding'].replace({'Not Specified': np.nan, '0': 0}).astype(float)

# %%
num_cols = [
    'TotalPremium', 'TotalClaims', 'SumInsured',
    'CalculatedPremiumPerTerm', 'CustomValueEstimate', 'CapitalOutstanding'
]
# Drop rows with missing values in these columns
df_box = df[num_cols].dropna()
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df_box[col])
    plt.title(f"Box Plot of {col}")
    plt.xlabel(col)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Drop rows with missing values in these columns
